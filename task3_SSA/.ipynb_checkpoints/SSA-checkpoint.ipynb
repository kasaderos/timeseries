# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('rub_usd.csv', sep=',')
#pd.to_datetime(raw_data['Mycol'], format='%d%b%Y:%H:%M:%S.%f')
data['Date'] = pd.to_datetime(data['Date'] + ' ' + data['<TIME>'])
p = 50
data2 = data.drop([i for i in range(len(data)-p, len(data))]) 
N = len(data2['Date'])
tau = int((N + 1) / 2) 
xt = np.array(data2['RUB/USD']) # ряд для построения модели

# %%
X = np.array([xt[i:(i+tau)] for i in range(N-tau+1)])
n = len(X[0])

# %%
C = 1 / n * X.transpose().dot(X)

# %%
w, V = np.linalg.eig(C)
W = np.diag(w)

# %%
#V.transpose().dot(C).dot(Vtau) # =W
#np.abs(np.linalg.det(C) - np.prod(w)) < 1e-3

# %%
Y = V.transpose().dot(X)

# %%
r = int(tau * 2 / 3)
Vr = V[:r]
Temp = Y.transpose()[:r]
Yr = Temp.transpose()

# %%
def S(P, V, r):
    return np.array([np.sum(P[i] * V[i]) for i in range(r)])

def findQ(xt, tau, N):
    return np.array([xt[i] for i in range(N-tau+1, N)]) 

def findNext(Vtau, Vstar, Q):
    return Vtau.dot(Vstar.transpose().dot(Q)) / (1 - Vtau.dot(Vtau.transpose()))

# %%
Q = findQ(xt, tau, N)
Vstar = np.array([V[i][:r] for i in range(tau-1)])
Vtau = np.array([V[len(V)-1][i] for i in range(r)])

# %%
#Vtau 912x608    -> VtauT 608x912   *   Q 912 -> M 912 
print(len(Vtau), len(Vstar), len(Q))
# Out:
# 456 683 683

# %%
# cycle
NewN = N
NewXt = [x for x in xt]
for i in range(p):
    Q = findQ(NewXt, tau, NewN)
    x_next = findNext(Vtau, Vstar, Q)
    NewXt.append(x_next)
    NewN += 1

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data['Date'],
                y=data['RUB/USD'],
                name="Data",
                line_color='deepskyblue',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=data['Date'],
                y=np.array(NewXt),
                name="Predict",
                line_color='red',
                opacity=0.8))

fig.show()
# Out:
# <div>
#
#
#             <div id="224dadde-79af-43c2-9f4f-e28c4bb972d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("224dadde-79af-43c2-9f4f-e28c4bb972d7")) {
#                     Plotly.newPlot(
#                         '224dadde-79af-43c2-9f4f-e28c4bb972d7',
#                         [{"line": {"color": "deepskyblue"}, "name": "Data", "opacity": 0.8, "type": "scatter", "x": ["2020-03-13T00:01:00", "2020-03-13T00:02:00", "2020-03-13T00:03:00", "2020-03-13T00:04:00", "2020-03-13T00:05:00", "2020-03-13T00:09:00", "2020-03-13T00:10:00", "2020-03-13T00:11:00", "2020-03-13T00:12:00", "2020-03-13T00:15:00", "2020-03-13T00:16:00", "2020-03-13T00:17:00", "2020-03-13T00:20:00", "2020-03-13T00:21:00", "2020-03-13T00:22:00", "2020-03-13T00:23:00", "2020-03-13T00:24:00", "2020-03-13T00:25:00", "2020-03-13T00:26:00", "2020-03-13T00:27:00", "2020-03-13T00:28:00", "2020-03-13T00:29:00", "2020-03-13T00:30:00", "2020-03-13T00:31:00", "2020-03-13T00:33:00", "2020-03-13T00:34:00", "2020-03-13T00:35:00", "2020-03-13T00:37:00", "2020-03-13T00:40:00", "2020-03-13T00:41:00", "2020-03-13T00:42:00", "2020-03-13T00:43:00", "2020-03-13T00:44:00", "2020-03-13T00:45:00", "2020-03-13T00:46:00", "2020-03-13T00:47:00", "2020-03-13T00:48:00", "2020-03-13T00:49:00", "2020-03-13T00:50:00", "2020-03-13T00:51:00", "2020-03-13T00:52:00", "2020-03-13T00:54:00", "2020-03-13T00:55:00", "2020-03-13T00